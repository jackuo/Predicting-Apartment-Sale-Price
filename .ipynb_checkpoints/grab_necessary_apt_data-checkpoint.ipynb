# %%
import pickle
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests
from collections import defaultdict

import re
from datetime import datetime
import glob

# %%
#apt1 = 'https://www.cityrealty.com/nyc/midtown-east/milan-300-east-55th-street/apartment-9B/sold/A11864'
#apt2 = 'https://cityrealty.com/nyc/midtown-east/the-galleria-117-east-57th-street/apartment-27G/sold/A10573'
#r1 = requests.get(apt1)
#r2 = requests.get(apt2)
#s1 = BeautifulSoup(r1.text, "lxml")
#s2 = BeautifulSoup(r2.text, "lxml")

# %%
#soup.find_all('div', {"ng-if" : "column.type === 'priceChangeDate'"})
#soup.find_all('div', {"class" : "ng-scope'"})
#soup.find('div', {"class": "sold_info"}).find_all("span")[2].text
#soup.find('div', {"cr-results-table-row class": "row ng-scope x sold"})
#soup.find('div', {"class": "beds_baths"}).text.strip()

#soup.find('div', class_ = "key_details section").find("span", class_ = "value").text.strip()

#count = 0

#for tag in soup.find('div', class_ = "key_details section"):
#    try:
#        print(tag.text)
#        print(type(tag))
#        print(count)
#    except:
#        continue
    
    #print(type(tag))
    #print(tag)
    #print(count)
#    count = count + 1


#test = {}

#count = 0
#for row in soup.find_all('div', {"class" : "row"}):
#    for title in row.find_all("span", {"class": "title"}):
        #print(count)
        #print(title.text.strip())
        #count = count + 1
#        for value in row.find_all("span", {"class": "value"}):
            #print(count)
            #print(value.text.strip())
#            test[title.text.strip()] = value.text.strip()

# %%
def create_apt_dict(soup):

    apt_dict = {}

    # Full Name
    try:
        apt_dict['full_name'] = soup.find_all('h1', {"class" : "bld_title"})[0].text.strip()
    except:
        apt_dict['full_name'] = np.nan
    
    
    # Buidling Name
    try:
        apt_dict['bldg_name'] = soup.find_all('h1', {"class" : "bld_title"})[0].text.strip().split(",")[0].strip()
    except:
        apt_dict['bldg_name'] = np.nan
    
    
    # Building Address
    try:
        apt_dict['bldg_addr'] = soup.find_all('h1', {"class" : "bld_title"})[0].text.strip().split(",")[1].strip()
    except:
        apt_dict['bldg_addr'] = ""
    
    
    # Apt Floor
    try:
        apt_num = str(soup.find_all('h1', {"class" : "bld_title"})[0].text.strip().split(",")[2])
        apt_dict['apt_floor'] = int(re.findall('\d+', apt_num)[0])
    except:
        apt_dict['apt_floor'] = np.nan
        
    
    # Rating
    try:
        rating = str(soup.find_all('h1')[1].text.split("CityRealty Rating")[1])
        apt_dict['bldg_rating'] = int(re.findall('\d+', rating)[0])
    except:
        apt_dict['bldg_rating'] = np.nan


    # Sold day
    try:
        apt_dict['sold_date'] = soup.find('div', {"class": "brief"}).find("strong").text
    except:
        apt_dict['sold_date'] = ""
    
    
    # Sold day datetime
    try:
        day_dt = soup.find('div', {"class": "brief"}).find("strong").text
        apt_dict['sold_date_dt'] = datetime.strptime(day_dt.split('Last Sold on ')[1], "%b %d, %Y")
    except:
        apt_dict['sold_date_dt'] = np.nan


    # Sold Price
    try:
        apt_dict['sold_price'] = (float(soup
                                        .find('div', {"class": "sold_info"})
                                        .find_all("span")[2]
                                        .text.strip()[1:]
                                        .replace(",", "")))
    except:
        try:
            value = (soup
                     .find('div', {"class": "sold_info"})
                     .find_all("span")[0]
                     .text.strip()
                     .split("$",1)[1]
                     .split("(", 1)[0].strip())
            
            apt_dict['sold_price'] = float(value.replace(",", ""))
        except:
            apt_dict['sold_price'] = ""


    # Price Per Square Foot
    try:
        apt_dict['price_per_sqft'] = (float(soup
                                            .find('div', {"class": "sold_info"})
                                            .find_all("span")[3]
                                            .text
                                            .strip()
                                            .split("/", 1)[0]
                                            .strip()[2:]
                                            .replace(",", "")))
    except:
        try:
            apt_dict['price_per_sqft'] = (float(s1
                                                .find('div', {"class": "sold_info"})
                                                .find_all("span")[0]
                                                .text.strip()
                                                .split("(", 1)[1]
                                                .split("/", 1)[0]
                                                .strip()[1:]
                                                .replace(",", "")))
        except:    
            apt_dict['price_per_sqft'] = np.nan
          
        
    # Square Feet
    try:
        apt_dict['square_feet'] = round(apt_dict['sold_price'] / apt_dict['price_per_sqft'])
    except:
        apt_dict['square_feet'] = np.nan
    
    
    # Beds Baths
    try:
        apt_dict['bed_and_bath'] = soup.find('div', {"class": "beds_baths"}).text.strip()
    except:
        apt_dict['bed_and_bath'] = np.nan
    
    
    # Beds
    try:
        bed = soup.find('div', {"class": "beds_baths"}).text.strip().split(",")[0]
        apt_dict['beds'] = float(re.findall('\d+', bed)[0])
    except:
        apt_dict['beds'] = np.nan

        
    # Baths
    try:
        apt_dict['baths'] = (float(soup
                                   .find('div', {"class": "beds_baths"})
                                   .text.strip()
                                   .split(",")[1]
                                   .strip()
                                   .split(" ")[0]))
    except:
        apt_dict['baths'] = np.nan
        

    # Date Listed
    #try:
    #    date_listed = soup.find('div', class_ = "key_details section").find("span", class_ = "value").text.strip()
    #    apt_dict['date_listed'] = datetime.strptime(date_listed, "%b %d, %Y")
    #except:
    #    apt_dict['date_listed'] = ""


    # Table Data
    try:
        for row in soup.find_all('div', {"class" : "row"}):  # Look at each row in the div (entry in table)
            for title in row.find_all("span", {"class": "title"}):  # pull out the titles
                for value in row.find_all("span", {"class": "value"}): # pull out the values
                    apt_dict[title.text.strip()] = value.text.strip()
    except:
        None
    
    
    # Monthly Common Charges
    try:
        apt_dict['Monthly Common Charges'] = float(apt_dict['Monthly Common Charges'][1:].replace(",", ""))
    except:
        None
    
    
    # Monthly Taxes
    try:
        apt_dict['Monthly Real Estate Taxes'] = float(apt_dict['Monthly Real Estate Taxes'][1:].replace(",", ""))
    except:
        None
    
    
    # Minimum Down Payment
    try:
        apt_dict['Minimum Down Payment'] = float(apt_dict['Minimum Down Payment'].strip('%'))/100
    except:
        None
    
    
    # Date Listed
    try:
        apt_dict['Listed'] = datetime.strptime(apt_dict['Listed'], "%b %d, %Y")
    except:
        None
    
    return(apt_dict)

# %% [markdown]
# # Pulling the location of each file

# %%
import glob

pickle_file_path = '/Users/JacKuo14/Documents/Metis/course_work/city_realty_data/projet02_cityrealty/*.pkl'

file_list = glob.glob(pickle_file_path)

# %%
def get_files(folder_path):
    
    picke_file_path = "{}/*.pkl".format(folder_path)
    file_list = glob.glob(pickle_file_path)
    
    return(file_list)

# %%
list_of_dict = []

c = 0

for file in file_list:
    print(file)
    
    # unpickle file
    with open(file, 'rb') as picklefile: 
        data = pickle.load(picklefile)
    
    # create beautiful soup
    soup = BeautifulSoup(data, "lxml")
    
    # create dictionary from soup
    apt_dict = create_apt_dict(soup)
    
    # append to list
    list_of_dict.append(apt_dict)
    
    print("# of Apts: ", str(c))
    c = c + 1
# Out:
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_977.pkl
# # of Apts:  3095
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_978.pkl
# # of Apts:  3096
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_979.pkl
# # of Apts:  3097
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_98.pkl
# # of Apts:  3098
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_980.pkl
# # of Apts:  3099
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_981.pkl
# # of Apts:  3100
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_982.pkl
# # of Apts:  3101
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_983.pkl
# # of Apts:  3102
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_984.pkl
# # of Apts:  3103
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_985.pkl
# # of Apts:  3104
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_986.pkl
# # of Apts:  3105
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_987.pkl
# # of Apts:  3106
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_988.pkl
# # of Apts:  3107
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_989.pkl
# # of Apts:  3108
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_99.pkl
# # of Apts:  3109
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_990.pkl
# # of Apts:  3110
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_991.pkl
# # of Apts:  3111
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_992.pkl
# # of Apts:  3112
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_993.pkl
# # of Apts:  3113
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_994.pkl
# # of Apts:  3114
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_995.pkl
# # of Apts:  3115
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_996.pkl
# # of Apts:  3116
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_997.pkl
# # of Apts:  3117
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_998.pkl
# # of Apts:  3118
# /Users/JacKuo14/Documents/Metis/course_work/city_realty_data/apt_999.pkl
# # of Apts:  3119

# %%
#list(apt_dict.keys())

# %%
df = pd.DataFrame(list_of_dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3120 entries, 0 to 3119
# Data columns (total 22 columns):
# full_name                    3120 non-null object
# bldg_name                    3120 non-null object
# bldg_addr                    3120 non-null object
# apt_floor                    2489 non-null float64
# bldg_rating                  3011 non-null float64
# sold_date                    3120 non-null object
# sold_date_dt                 3120 non-null datetime64[ns]
# sold_price                   3120 non-null float64
# price_per_sqft               3120 non-null float64
# square_feet                  3120 non-null int64
# bed_and_bath                 3120 non-null object
# beds                         2699 non-null float64
# baths                        3114 non-null float64
# Listed                       1746 non-null datetime64[ns]
# Days on Market               1746 non-null object
# Building Type                1746 non-null object
# Neighborhood                 1746 non-null object
# Monthly Common Charges       1732 non-null float64
# Monthly Real Estate Taxes    1644 non-null float64
# Minimum Down Payment         1109 non-null float64
# Doorman                      1630 non-null object
# Last Price Change            21 non-null object
# dtypes: datetime64[ns](2), float64(9), int64(1), object(10)
# memory usage: 536.4+ KB

# %%
pd.set_option('display.max_columns', 500)

df.head()
# Out:
#                                       full_name             bldg_name  \
# 0  The Cosmopolitan, 145 East 48th Street, #25G      The Cosmopolitan
# 1           Trump Tower, 721 Fifth Avenue, #37D           Trump Tower
# 2                     211 East 51st Street, #5D  211 East 51st Street
# 3              Milan, 300 East 55th Street, #9B                 Milan
# 4           Trump Tower, 721 Fifth Avenue, #54C           Trump Tower
#
#               bldg_addr  apt_floor  bldg_rating                  sold_date  \
# 0  145 East 48th Street       25.0         78.0  Last Sold on Sep 25, 2019
# 1      721 Fifth Avenue       37.0         94.0   Last Sold on Sep 3, 2019
# 2                   #5D        NaN         74.0  Last Sold on Jan 17, 2019
# 3  300 East 55th Street        9.0         80.0  Last Sold on Sep 19, 2013
# 4      721 Fifth Avenue       54.0         94.0  Last Sold on Sep 19, 2013
#
#   sold_date_dt  sold_price  price_per_sqft  square_feet       bed_and_bath  \
# 0   2019-09-25    799000.0          1229.0          650      1 bed, 1 bath
# 1   2019-09-03   2299000.0          2105.0         1092   1 bed, 1.5 baths
# 2   2019-01-17    641497.0          1270.0          505      1 bed, 1 bath
# 3   2013-09-19   2950000.0          1922.0         1535  2 beds, 2.5 baths
# 4   2013-09-19   2250000.0          2045.0         1100   1 bed, 1.5 baths
#
#    beds  baths     Listed Days on Market Building Type  Neighborhood  \
# 0   1.0    1.0 2019-04-12            174   Condominium  Midtown East
# 1   1.0    1.5 2019-01-02            274   Condominium  Midtown East
# 2   1.0    1.0        NaT            NaN           NaN           NaN
# 3   2.0    2.5 2013-03-08           2401   Condominium  Midtown East
# 4   1.0    1.5 2013-09-23           2202   Condominium  Midtown East
#
#    Monthly Common Charges  Monthly Real Estate Taxes  Minimum Down Payment  \
# 0                   814.0                      948.0                   0.1
# 1                  2036.0                     2061.0                   0.1
# 2                     NaN                        NaN                   NaN
# 3                  2108.0                     1350.0                   0.1
# 4                  1748.0                     1419.0                   0.1
#
#       Doorman Last Price Change
# 0  FT Doorman               NaN
# 1  FT Doorman               NaN
# 2         NaN               NaN
# 3  FT Doorman               NaN
# 4  FT Doorman               NaN

# %%
### Data Cleaning ###

# Adding Seasons
df['sold_season'] = (df['sold_date_dt']
                     .dt
                     .month
                     .map({1 : 'Winter', 
                           2 : 'Winter',
                           3 : 'Spring',
                           4 : 'Spring',
                           5 : 'Spring',
                           6 : 'Summer',
                           7 : 'Summer',
                           8 : 'Summer',
                           9 : 'Fall',
                           10 : 'Fall',
                           11 : 'Fall',
                           12 : 'Winter'}))

# Filling NAs with Studio
df['beds'] = df['beds'].fillna(0)

# %%
# Sort values by date sold
df = df.sort_values(by = 'sold_date_dt', ascending = False)

# Drop duplicate rows
df_no_dup = df.drop_duplicates(subset = 'full_name', keep = 'first').reset_index(drop = True)

# %%
df_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
# full_name                    2000 non-null object
# bldg_name                    2000 non-null object
# bldg_addr                    2000 non-null object
# apt_floor                    1549 non-null float64
# bldg_rating                  1929 non-null float64
# sold_date                    2000 non-null object
# sold_date_dt                 2000 non-null datetime64[ns]
# sold_price                   2000 non-null float64
# price_per_sqft               2000 non-null float64
# square_feet                  2000 non-null int64
# bed_and_bath                 2000 non-null object
# beds                         2000 non-null float64
# baths                        1996 non-null float64
# Listed                       981 non-null datetime64[ns]
# Days on Market               981 non-null object
# Building Type                981 non-null object
# Neighborhood                 981 non-null object
# Monthly Common Charges       971 non-null float64
# Monthly Real Estate Taxes    892 non-null float64
# Minimum Down Payment         581 non-null float64
# Doorman                      904 non-null object
# Last Price Change            14 non-null object
# sold_season                  2000 non-null object
# dtypes: datetime64[ns](2), float64(9), int64(1), object(11)
# memory usage: 359.5+ KB

# %% [markdown]
# ## How do you replace zeros with another column?
#
# Want to replace zeros of apt floor with regex extract number from another column

# %%
df_no_dup.columns
# Out:
# Index(['full_name', 'bldg_name', 'bldg_addr', 'apt_floor', 'bldg_rating',
#        'sold_date', 'sold_date_dt', 'sold_price', 'price_per_sqft',
#        'square_feet', 'bed_and_bath', 'beds', 'baths', 'Listed',
#        'Days on Market', 'Building Type', 'Neighborhood',
#        'Monthly Common Charges', 'Monthly Real Estate Taxes',
#        'Minimum Down Payment', 'Doorman', 'Last Price Change', 'sold_season'],
#       dtype='object')

# %%
for index, row in df_apt_na.iterrows():
    #print(row['apt_floor'])
    #print(np.isnan(row['apt_floor']))
    try:
        if np.isnan(row['apt_floor']):
            df_no_dup.loc[index, 'apt_floor'] = int(re.findall('\d+', row['bldg_addr'])[0]) # assign value in full dataframe
            df_no_dup.loc[index, 'bldg_addr'] = df_no_dup.loc[index]['bldg_name'] # move building address over to correct column
            df_no_dup.loc[index, 'bldg_name'] = np.nan # clears building name
            #print(index)
        else:
            continue
    except:
        continue

# %%
df_no_dup[df_no_dup['apt_floor'].isna()]
# Out:
#                         full_name             bldg_name bldg_addr  apt_floor  \
# 387   141 East 55th Street, #PH B  141 East 55th Street     #PH B        NaN
# 863   141 East 55th Street, #PH C  141 East 55th Street     #PH C        NaN
# 1305  140 East 56th Street, #PH-D  140 East 56th Street     #PH-D        NaN
# 1410  140 East 56th Street, #PH-A  140 East 56th Street     #PH-A        NaN
#
#       bldg_rating                  sold_date sold_date_dt  sold_price  \
# 387          61.0  Last Sold on Dec 27, 2016   2016-12-27    920000.0
# 863          61.0  Last Sold on Apr 11, 2014   2014-04-11    995000.0
# 1305         45.0  Last Sold on Jan 25, 2010   2010-01-25    300000.0
# 1410         45.0   Last Sold on Aug 8, 2008   2008-08-08    965000.0
#
#       price_per_sqft  square_feet    bed_and_bath  beds  baths     Listed  \
# 387           1278.0          720   1 bed, 1 bath   1.0    1.0 2015-04-21
# 863           1792.0          555  2 beds, 1 bath   2.0    1.0 2014-02-10
# 1305          1792.0          167   1 bed, 1 bath   1.0    1.0        NaT
# 1410          1792.0          539   1 bed, 1 bath   1.0    1.0        NaT
#
#      Days on Market Building Type  Neighborhood  Monthly Common Charges  \
# 387            1626   Condominium  Midtown East                   924.0
# 863            2061   Condominium  Midtown East                  1023.0
# 1305            NaN           NaN           NaN                     NaN
# 1410            NaN           NaN           NaN                     NaN
#
#       Monthly Real Estate Taxes  Minimum Down Payment     Doorman  \
# 387                       783.0                   NaN  FT Doorman
# 863                       750.0                   NaN  FT Doorman
# 1305                        NaN                   NaN         NaN
# 1410                        NaN                   NaN         NaN
#
#      Last Price Change sold_season
# 387                NaN      Winter
# 863                NaN      Spring
# 1305               NaN      Winter
# 1410               NaN      Summer

# %% [markdown]
# # Cleaning Data

# %%
# = ['sold_price']
#model_columns = ['apt_floor', 'bldg_rating', 'sold_season', 'square_feet', 'beds', 'baths', 'sold_price']
target = ['sold_price']
model_columns = ['bldg_rating', 'sold_season', 'square_feet', 'beds', 'baths', 'sold_price']

smaller_df = df_no_dup.loc[:, model_columns]

# %%
# filter!
#mask = ((smaller_df['apt_floor'] != 3303) & (smaller_df['square_feet'] != 10562))
mask = ((smaller_df['square_feet'] != 10562))

# %%
smaller_df[mask].describe()
# Out:
#        bldg_rating  square_feet         beds        baths    sold_price
# count  1928.000000  1999.000000  1999.000000  1995.000000  1.999000e+03
# mean     77.300830  1010.796898     1.313657     1.663910  1.804086e+06
# std      12.781415   851.576847     0.700471     0.633367  1.858064e+06
# min      45.000000    78.000000     0.000000     1.000000  1.400000e+05
# 25%      70.000000   507.500000     1.000000     1.000000  7.550000e+05
# 50%      80.000000   878.000000     1.000000     1.500000  1.350000e+06
# 75%      85.000000  1320.500000     2.000000     2.000000  2.250000e+06
# max      96.000000  9768.000000     3.000000     3.500000  1.762500e+07

# %%
smaller_df = smaller_df[mask]

# %%
smaller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 0 to 1999
# Data columns (total 6 columns):
# bldg_rating    1928 non-null float64
# sold_season    1999 non-null object
# square_feet    1999 non-null int64
# beds           1999 non-null float64
# baths          1995 non-null float64
# sold_price     1999 non-null float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 109.3+ KB

# %%
smaller_df = smaller_df.dropna(how = 'any')

# %%
smaller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1924 entries, 0 to 1999
# Data columns (total 6 columns):
# bldg_rating    1924 non-null float64
# sold_season    1924 non-null object
# square_feet    1924 non-null int64
# beds           1924 non-null float64
# baths          1924 non-null float64
# sold_price     1924 non-null float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 105.2+ KB

# %%
import seaborn as sns
# %matplotlib inline
sns.set()
sns.pairplot(smaller_df, diag_kind='kde')

# %%
smaller_df.corr()
# Out:
#              bldg_rating  square_feet      beds     baths  sold_price
# bldg_rating     1.000000     0.418541  0.279038  0.467157    0.449774
# square_feet     0.418541     1.000000  0.462570  0.638309    0.902368
# beds            0.279038     0.462570  1.000000  0.786187    0.427378
# baths           0.467157     0.638309  0.786187  1.000000    0.623855
# sold_price      0.449774     0.902368  0.427378  0.623855    1.000000

# %%
sns.distplot(smaller_df['sold_price'])

# %%
categorical = ['sold_season']
continuous = ['bldg_rating', 'square_feet', 'beds', 'baths']

smaller_df = pd.get_dummies(smaller_df)
smaller_df.head()
# Out:
#    bldg_rating  square_feet  beds  baths  sold_price  sold_season_Fall  \
# 0         78.0          650   1.0    1.0    799000.0                 1
# 1         70.0          907   1.0    1.0   1739990.0                 1
# 2         80.0         1441   2.0    2.5   1782000.0                 1
# 3         62.0         1420   2.0    2.0   1800000.0                 1
# 4         91.0         1209   2.0    2.0   2195000.0                 1
#
#    sold_season_Spring  sold_season_Summer  sold_season_Winter
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0

# %% [markdown]
# # Model

# %%
# Necessary imports
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge #ordinary linear regression + w/ ridge regularization
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
smaller_df.head()
# Out:
#    bldg_rating sold_season  square_feet  beds  baths  sold_price
# 0         78.0        Fall          650   1.0    1.0    799000.0
# 1         70.0        Fall          907   1.0    1.0   1739990.0
# 2         80.0        Fall         1441   2.0    2.5   1782000.0
# 3         62.0        Fall         1420   2.0    2.0   1800000.0
# 4         91.0        Fall         1209   2.0    2.0   2195000.0

# %%
target = ['sold_price']
categorical = ['sold_season']
continuous = ['bldg_rating', 'square_feet', 'beds', 'baths']

X = smaller_df.drop('sold_price', axis = 1)
y = smaller_df['sold_price']

# %%
# hold out 20% of the data for final testing
X, X_test, y, y_test = train_test_split(X, y, test_size=.2, random_state=10)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, shuffle=True, random_state = 1000)

lm = LinearRegression()

np.mean(cross_val_score(lm, X, y, # estimator, features, target
                cv=kf, # number of folds 
                scoring='r2')) # scoring metric
# Out:
# 0.82855763584414

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

lm_reg = Ridge(alpha=1)

np.mean(cross_val_score(lm_reg, X, y, cv=kf, scoring = 'r2'))
#mean(cross_val_score)
# Out:
# 0.8285620865463255
