# %%
import pickle
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests
from collections import defaultdict

import re
from datetime import datetime
import glob

# %%
def clean_function(df):
    # Sort values by date sold
    df = df.sort_values(by = 'sold_date_dt', ascending = False)

    # Drop duplicate rows
    df_no_dup = df.drop_duplicates(subset = 'full_name', keep = 'first').reset_index(drop = True)
    
    # Add season
    df_no_dup['sold_season'] = (df_no_dup['sold_date_dt']
                         .dt
                         .month
                         .map({1 : 'Winter', 
                               2 : 'Winter',
                               3 : 'Spring',
                               4 : 'Spring',
                               5 : 'Spring',
                               6 : 'Summer',
                               7 : 'Summer',
                               8 : 'Summer',
                               9 : 'Fall',
                               10 : 'Fall',
                               11 : 'Fall',
                               12 : 'Winter'}))
    
    # Fill to indicate Studio
    df_no_dup['beds'] = df_no_dup['beds'].fillna(0)
    
    ### Fixing rows where there is no condo ###
    # Find where apt = NaN
    df_apt_na = df_no_dup[df_no_dup['apt_floor'].isna()]

    # 
    for index, row in df_apt_na.iterrows():
        #print(row['apt_floor'])
        #print(np.isnan(row['apt_floor']))
        try:
            if np.isnan(row['apt_floor']):
                df_no_dup.loc[index, 'apt_floor'] = int(re.findall('\d+', row['bldg_addr'])[0]) # assign value in full dataframe
                df_no_dup.loc[index, 'bldg_addr'] = df_no_dup.loc[index]['bldg_name'] # move building address over to correct column
                df_no_dup.loc[index, 'bldg_name'] = np.nan # clears building name
                #print(index)
            else:
                continue
        except:
            continue
    
    
    return(df_no_dup)
# Out:
#   File "<ipython-input-25-02c86efbe36c>", line 10
#     def add_season_col(df_no_dup[col]):
#                                 ^
# SyntaxError: invalid syntax

# %%
with open("all_midtown_data.pkl", "rb") as picklefile:
    df = pickle.load(picklefile)

# %%
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#                                         full_name           bldg_name  \
# 0      Worldwide Plaza, 393 West 49th Street, #3P     Worldwide Plaza
# 1  Central Park Place, 301 West 57th Street, #24E  Central Park Place
# 2       The Platinum, 247 West 46th Street, #2502        The Platinum
# 3               One57, 157 West 57th Street, #35B               One57
# 4        Clinton West, 516 West 47th Street, #S6J        Clinton West
#
#               bldg_addr  apt_floor  bldg_rating                  sold_date  \
# 0  393 West 49th Street        3.0         73.0  Last Sold on Sep 27, 2019
# 1  301 West 57th Street       24.0         85.0  Last Sold on Sep 20, 2019
# 2  247 West 46th Street     2502.0         80.0   Last Sold on Aug 6, 2019
# 3  157 West 57th Street       35.0         94.0  Last Sold on Jul 31, 2018
# 4  516 West 47th Street        6.0         62.0   Last Sold on May 2, 2013
#
#   sold_date_dt  sold_price  price_per_sqft  square_feet       bed_and_bath  \
# 0   2019-09-27    545000.0             NaN          NaN     Studio, 1 bath
# 1   2019-09-20    750000.0          1752.0        428.0     Studio, 1 bath
# 2   2019-08-06   1450000.0          1451.0        999.0   1 bed, 1.5 baths
# 3   2018-07-31   8975000.0          4184.0       2145.0  2 beds, 2.5 baths
# 4   2013-05-02    525000.0          1117.0        470.0      1 bed, 1 bath
#
#    beds  baths                                                url     Listed  \
# 0   NaN    1.0  https://www.cityrealty.com/nyc/midtown-west/wo...        NaT
# 1   NaN    1.0  https://www.cityrealty.com/nyc/midtown-west/ce... 2019-05-13
# 2   1.0    1.5  https://www.cityrealty.com/nyc/midtown-west/th... 2019-02-21
# 3   2.0    2.5  https://www.cityrealty.com/nyc/midtown-west/on... 2018-05-02
# 4   1.0    1.0  https://www.cityrealty.com/nyc/midtown-west/cl... 2012-08-10
#
#   Days on Market Building Type  Neighborhood  Monthly Common Charges  \
# 0            NaN           NaN           NaN                     NaN
# 1            145   Condominium  Midtown West                   457.0
# 2            226   Condominium  Midtown West                  1041.0
# 3            521   Condominium  Midtown West                  2690.0
# 4           2613   Condominium  Midtown West                   514.0
#
#    Monthly Real Estate Taxes  Minimum Down Payment     Doorman  \
# 0                        NaN                   NaN         NaN
# 1                      498.0                   0.1  FT Doorman
# 2                     1347.0                   NaN  FT Doorman
# 3                     2109.0                   NaN  FT Doorman
# 4                      260.0                   NaN  FT Doorman
#
#   Last Price Change
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df_no_dup = drop_duplicates(df) # function above.
df_no_dup['sold_season'] = add_season_col(df_no_dup['sold_date_dt']) # function above.

# %%
### Data Cleaning ###

# Adding Seasons
df['sold_season'] = (df['sold_date_dt']
                     .dt
                     .month
                     .map({1 : 'Winter', 
                           2 : 'Winter',
                           3 : 'Spring',
                           4 : 'Spring',
                           5 : 'Spring',
                           6 : 'Summer',
                           7 : 'Summer',
                           8 : 'Summer',
                           9 : 'Fall',
                           10 : 'Fall',
                           11 : 'Fall',
                           12 : 'Winter'}))

# Filling NAs with Studio
df['beds'] = df['beds'].fillna(0)

# %%
# Sort values by date sold
df = df.sort_values(by = 'sold_date_dt', ascending = False)

# Drop duplicate rows
df_no_dup = df.drop_duplicates(subset = 'full_name', keep = 'first').reset_index(drop = True)

# %%
df_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14841 entries, 0 to 14840
# Data columns (total 24 columns):
# full_name                    14841 non-null object
# bldg_name                    14841 non-null object
# bldg_addr                    14841 non-null object
# apt_floor                    12497 non-null float64
# bldg_rating                  14235 non-null float64
# sold_date                    14841 non-null object
# sold_date_dt                 14841 non-null datetime64[ns]
# sold_price                   14841 non-null float64
# price_per_sqft               6449 non-null float64
# square_feet                  6449 non-null float64
# bed_and_bath                 14841 non-null object
# beds                         14841 non-null float64
# baths                        14815 non-null float64
# url                          14841 non-null object
# Listed                       7088 non-null datetime64[ns]
# Days on Market               7088 non-null object
# Building Type                7088 non-null object
# Neighborhood                 7088 non-null object
# Monthly Common Charges       7011 non-null float64
# Monthly Real Estate Taxes    6712 non-null float64
# Minimum Down Payment         2858 non-null float64
# Doorman                      6665 non-null object
# Last Price Change            106 non-null object
# sold_season                  14841 non-null object
# dtypes: datetime64[ns](2), float64(10), object(12)
# memory usage: 2.7+ MB

# %%
target = ['sold_price']
cont = ['bldg_rating', 'sold_season', 'beds', 'baths', 'Monthly Common Charges', 'Monthly Real Estate Taxes']
cat = ['square_feet', 'Neighborhood', '']

# %% [markdown]
# ## How do you replace zeros with another column?
#
# Want to replace zeros of apt floor with regex extract number from another column

# %%
df_apt_na = df_no_dup[df_no_dup['apt_floor'].isna()]

# %%
def fill_apt_na(df_no_dup):
    df_apt_na = df_no_dup[df_no_dup['apt_floor'].isna()]

    for index, row in df_apt_na.iterrows():
        #print(row['apt_floor'])
        #print(np.isnan(row['apt_floor']))
        try:
            if np.isnan(row['apt_floor']):
                df_no_dup.loc[index, 'apt_floor'] = int(re.findall('\d+', row['bldg_addr'])[0]) # assign value in full dataframe
                df_no_dup.loc[index, 'bldg_addr'] = df_no_dup.loc[index]['bldg_name'] # move building address over to correct column
                df_no_dup.loc[index, 'bldg_name'] = np.nan # clears building name
                #print(index)
            else:
                continue
        except:
            continue
    
    return()

# %%
df_apt_na = df_no_dup[df_no_dup['apt_floor'].isna()]

for index, row in df_apt_na.iterrows():
    #print(row['apt_floor'])
    #print(np.isnan(row['apt_floor']))
    try:
        if np.isnan(row['apt_floor']):
            df_no_dup.loc[index, 'apt_floor'] = int(re.findall('\d+', row['bldg_addr'])[0]) # assign value in full dataframe
            df_no_dup.loc[index, 'bldg_addr'] = df_no_dup.loc[index]['bldg_name'] # move building address over to correct column
            df_no_dup.loc[index, 'bldg_name'] = np.nan # clears building name
            #print(index)
        else:
            continue
    except:
        continue

# %%
df_no_dup[df_no_dup['apt_floor'].isna()]
# Out:
#                           full_name             bldg_name bldg_addr  \
# 25             80 Park Avenue, #PHA        80 Park Avenue      #PHA
# 2295     432 West 52nd Street, #GDA  432 West 52nd Street      #GDA
# 2636     432 West 52nd Street, #GDF  432 West 52nd Street      #GDF
# 2677    141 East 55th Street, #PH B  141 East 55th Street     #PH B
# 3152   444 East 57th Street, #PHE/F  444 East 57th Street    #PHE/F
# 4372     432 West 52nd Street, #GDB  432 West 52nd Street      #GDB
# 4523     432 West 52nd Street, #GDD  432 West 52nd Street      #GDD
# 4587     432 West 52nd Street, #GDG  432 West 52nd Street      #GDG
# 4940     432 West 52nd Street, #GDC  432 West 52nd Street      #GDC
# 4942     303 East 33rd Street, #PHB  303 East 33rd Street      #PHB
# 4943     432 West 52nd Street, #GDE  432 West 52nd Street      #GDE
# 5860    141 East 55th Street, #PH C  141 East 55th Street     #PH C
# 7437          71 Park Avenue, #PH-A        71 Park Avenue     #PH-A
# 7967     240 East 46th Street, #PHA  240 East 46th Street      #PHA
# 7970     303 East 33rd Street, #PHA  303 East 33rd Street      #PHA
# 7978    155 East 38th Street, #PH-D  155 East 38th Street     #PH-D
# 8298     303 East 33rd Street, #PHC  303 East 33rd Street      #PHC
# 8458     303 East 33rd Street, #PHH  303 East 33rd Street      #PHH
# 8729     303 East 33rd Street, #PHF  303 East 33rd Street      #PHF
# 8800     303 East 33rd Street, #PHD  303 East 33rd Street      #PHD
# 8816     303 East 33rd Street, #PHE  303 East 33rd Street      #PHE
# 9526    140 East 56th Street, #PH-D  140 East 56th Street     #PH-D
# 10393   140 East 56th Street, #PH-A  140 East 56th Street     #PH-A
# 10690     40 West 55th Street, #PHS   40 West 55th Street      #PHS
# 12329     40 West 55th Street, #PHN   40 West 55th Street      #PHN
#
#        apt_floor  bldg_rating                  sold_date sold_date_dt  \
# 25           NaN         75.0  Last Sold on Sep 13, 2019   2019-09-13
# 2295         NaN         65.0  Last Sold on May 10, 2017   2017-05-10
# 2636         NaN         65.0   Last Sold on Jan 9, 2017   2017-01-09
# 2677         NaN         61.0  Last Sold on Dec 27, 2016   2016-12-27
# 3152         NaN         66.0  Last Sold on Jul 25, 2016   2016-07-25
# 4372         NaN         65.0  Last Sold on Aug 19, 2015   2015-08-19
# 4523         NaN         65.0   Last Sold on Jul 9, 2015   2015-07-09
# 4587         NaN         65.0  Last Sold on Jun 25, 2015   2015-06-25
# 4940         NaN         65.0  Last Sold on Mar 26, 2015   2015-03-26
# 4942         NaN         80.0  Last Sold on Mar 25, 2015   2015-03-25
# 4943         NaN         65.0  Last Sold on Mar 25, 2015   2015-03-25
# 5860         NaN         61.0  Last Sold on Apr 11, 2014   2014-04-11
# 7437         NaN         67.0  Last Sold on Aug 15, 2012   2012-08-15
# 7967         NaN         57.0  Last Sold on Jan 17, 2012   2012-01-17
# 7970         NaN         80.0  Last Sold on Jan 13, 2012   2012-01-13
# 7978         NaN         60.0  Last Sold on Jan 11, 2012   2012-01-11
# 8298         NaN         80.0  Last Sold on Jul 29, 2011   2011-07-29
# 8458         NaN         80.0   Last Sold on Jun 2, 2011   2011-06-02
# 8729         NaN         80.0   Last Sold on Feb 1, 2011   2011-02-01
# 8800         NaN         80.0   Last Sold on Jan 7, 2011   2011-01-07
# 8816         NaN         80.0  Last Sold on Dec 28, 2010   2010-12-28
# 9526         NaN         45.0  Last Sold on Jan 25, 2010   2010-01-25
# 10393        NaN         45.0   Last Sold on Aug 8, 2008   2008-08-08
# 10690        NaN          NaN   Last Sold on May 1, 2008   2008-05-01
# 12329        NaN          NaN  Last Sold on Oct 12, 2006   2006-10-12
#
#        sold_price  price_per_sqft  square_feet       bed_and_bath  beds  \
# 25       598000.0             NaN          NaN     Studio, 1 bath   0.0
# 2295    1775000.0             NaN          NaN  2 beds, 1.5 baths   2.0
# 2636     840056.0             NaN          NaN   1 bed, 1.5 baths   1.0
# 2677     920000.0          1278.0        720.0      1 bed, 1 bath   1.0
# 3152    3850000.0          1774.0       2170.0  2 beds, 2.5 baths   2.0
# 4372    1725934.0             NaN          NaN   1 bed, 1.5 baths   1.0
# 4523    1950000.0             NaN          NaN   1 bed, 1.5 baths   1.0
# 4587    1013159.0             NaN          NaN      1 bed, 1 bath   1.0
# 4940    1624109.0             NaN          NaN   1 bed, 1.5 baths   1.0
# 4942    2895000.0          1786.0       1621.0    2 beds, 2 baths   2.0
# 4943     646589.0             NaN          NaN      1 bed, 1 bath   1.0
# 5860     995000.0             NaN          NaN     2 beds, 1 bath   2.0
# 7437    1999000.0             NaN          NaN    2 beds, 2 baths   2.0
# 7967     797500.0          1312.0        608.0      1 bed, 1 bath   1.0
# 7970    1995000.0          1295.0       1541.0    2 beds, 2 baths   2.0
# 7978    1395000.0             NaN          NaN    2 beds, 2 baths   2.0
# 8298    1995000.0          1414.0       1411.0    2 beds, 2 baths   2.0
# 8458    1625000.0          1341.0       1212.0    2 beds, 2 baths   2.0
# 8729    1595000.0          1535.0       1039.0    2 beds, 2 baths   2.0
# 8800     916425.0             NaN          NaN      1 bed, 1 bath   1.0
# 8816     977520.0             NaN          NaN      1 bed, 1 bath   1.0
# 9526     300000.0             NaN          NaN      1 bed, 1 bath   1.0
# 10393    965000.0             NaN          NaN      1 bed, 1 bath   1.0
# 10690   1545000.0             NaN          NaN   1 bed, 1.5 baths   1.0
# 12329   1825000.0             NaN          NaN     2 beds, 1 bath   2.0
#
#        baths                                                url     Listed  \
# 25       1.0  https://www.cityrealty.com/nyc/murray-hill/80-... 2019-06-18
# 2295     1.5  https://www.cityrealty.com/nyc/midtown-west/43...        NaT
# 2636     1.5  https://www.cityrealty.com/nyc/midtown-west/43...        NaT
# 2677     1.0  https://www.cityrealty.com/nyc/midtown-east/14... 2015-04-21
# 3152     2.5  https://www.cityrealty.com/nyc/beekman-sutton-...        NaT
# 4372     1.5  https://www.cityrealty.com/nyc/midtown-west/43...        NaT
# 4523     1.5  https://www.cityrealty.com/nyc/midtown-west/43...        NaT
# 4587     1.0  https://www.cityrealty.com/nyc/midtown-west/43...        NaT
# 4940     1.5  https://www.cityrealty.com/nyc/midtown-west/43...        NaT
# 4942     2.0  https://www.cityrealty.com/nyc/murray-hill/303... 2014-04-17
# 4943     1.0  https://www.cityrealty.com/nyc/midtown-west/43...        NaT
# 5860     1.0  https://www.cityrealty.com/nyc/midtown-east/14... 2014-02-10
# 7437     2.0  https://www.cityrealty.com/nyc/murray-hill/71-... 2012-08-21
# 7967     1.0  https://www.cityrealty.com/nyc/turtle-bay-unit... 2012-01-19
# 7970     2.0  https://www.cityrealty.com/nyc/murray-hill/303... 2009-05-05
# 7978     2.0  https://www.cityrealty.com/nyc/murray-hill/155... 2012-03-26
# 8298     2.0  https://www.cityrealty.com/nyc/murray-hill/303... 2010-06-17
# 8458     2.0  https://www.cityrealty.com/nyc/murray-hill/303... 2010-12-02
# 8729     2.0  https://www.cityrealty.com/nyc/murray-hill/303... 2009-05-05
# 8800     1.0  https://www.cityrealty.com/nyc/murray-hill/303...        NaT
# 8816     1.0  https://www.cityrealty.com/nyc/murray-hill/303...        NaT
# 9526     1.0  https://www.cityrealty.com/nyc/midtown-east/14...        NaT
# 10393    1.0  https://www.cityrealty.com/nyc/midtown-east/14...        NaT
# 10690    1.5  https://www.cityrealty.com/nyc/midtown-west/40...        NaT
# 12329    1.0  https://www.cityrealty.com/nyc/midtown-west/40...        NaT
#
#       Days on Market Building Type               Neighborhood  \
# 25               109   Condominium                Murray Hill
# 2295             NaN           NaN                        NaN
# 2636             NaN           NaN                        NaN
# 2677            1629   Condominium               Midtown East
# 3152             NaN           NaN                        NaN
# 4372             NaN           NaN                        NaN
# 4523             NaN           NaN                        NaN
# 4587             NaN           NaN                        NaN
# 4940             NaN           NaN                        NaN
# 4942            1998   Condominium                Murray Hill
# 4943             NaN           NaN                        NaN
# 5860            2064   Condominium               Midtown East
# 7437            2602   Condominium                Murray Hill
# 7967            2817   Condominium  Turtle Bay/United Nations
# 7970            3806   Condominium                Murray Hill
# 7978            2750   Condominium                Murray Hill
# 8298            3398   Condominium                Murray Hill
# 8458            3230   Condominium                Murray Hill
# 8729            3806   Condominium                Murray Hill
# 8800             NaN           NaN                        NaN
# 8816             NaN           NaN                        NaN
# 9526             NaN           NaN                        NaN
# 10393            NaN           NaN                        NaN
# 10690            NaN           NaN                        NaN
# 12329            NaN           NaN                        NaN
#
#        Monthly Common Charges  Monthly Real Estate Taxes  \
# 25                      565.0                      550.0
# 2295                      NaN                        NaN
# 2636                      NaN                        NaN
# 2677                    924.0                      783.0
# 3152                      NaN                        NaN
# 4372                      NaN                        NaN
# 4523                      NaN                        NaN
# 4587                      NaN                        NaN
# 4940                      NaN                        NaN
# 4942                   1459.0                     3454.0
# 4943                      NaN                        NaN
# 5860                   1023.0                      750.0
# 7437                   2083.0                     1582.0
# 7967                    701.0                      625.0
# 7970                   1456.0                      125.0
# 7978                   1457.0                     1176.0
# 8298                   1228.0                      105.0
# 8458                   1067.0                        NaN
# 8729                    922.0                        NaN
# 8800                      NaN                        NaN
# 8816                      NaN                        NaN
# 9526                      NaN                        NaN
# 10393                     NaN                        NaN
# 10690                     NaN                        NaN
# 12329                     NaN                        NaN
#
#        Minimum Down Payment     Doorman Last Price Change sold_season
# 25                      0.2  FT Doorman               NaN        Fall
# 2295                    NaN         NaN               NaN      Spring
# 2636                    NaN         NaN               NaN      Winter
# 2677                    NaN  FT Doorman               NaN      Winter
# 3152                    NaN         NaN               NaN      Summer
# 4372                    NaN         NaN               NaN      Summer
# 4523                    NaN         NaN               NaN      Summer
# 4587                    NaN         NaN               NaN      Summer
# 4940                    NaN         NaN               NaN      Spring
# 4942                    NaN  FT Doorman               NaN      Spring
# 4943                    NaN         NaN               NaN      Spring
# 5860                    NaN  FT Doorman               NaN      Spring
# 7437                    0.1  FT Doorman               NaN      Summer
# 7967                    NaN  FT Doorman               NaN      Winter
# 7970                    NaN  FT Doorman               NaN      Winter
# 7978                    0.1  FT Doorman               NaN      Winter
# 8298                    NaN  FT Doorman               NaN      Summer
# 8458                    NaN  FT Doorman               NaN      Summer
# 8729                    NaN  FT Doorman               NaN      Winter
# 8800                    NaN         NaN               NaN      Winter
# 8816                    NaN         NaN               NaN      Winter
# 9526                    NaN         NaN               NaN      Winter
# 10393                   NaN         NaN               NaN      Summer
# 10690                   NaN         NaN               NaN      Spring
# 12329                   NaN         NaN               NaN        Fall

# %% [markdown]
# # Cleaning Data

# %%
# = ['sold_price']
#model_columns = ['apt_floor', 'bldg_rating', 'sold_season', 'square_feet', 'beds', 'baths', 'sold_price']
target = ['sold_price']
model_columns = ['bldg_rating', 'sold_season', 'square_feet', 'beds', 'baths', 'sold_price']

smaller_df = df_no_dup.loc[:, model_columns]

# %%
# filter!
#mask = ((smaller_df['apt_floor'] != 3303) & (smaller_df['square_feet'] != 10562))
mask = ((smaller_df['square_feet'] != 10562))

# %%
smaller_df[mask].describe()
# Out:
#        bldg_rating  square_feet         beds        baths    sold_price
# count  1928.000000  1999.000000  1999.000000  1995.000000  1.999000e+03
# mean     77.300830  1010.796898     1.313657     1.663910  1.804086e+06
# std      12.781415   851.576847     0.700471     0.633367  1.858064e+06
# min      45.000000    78.000000     0.000000     1.000000  1.400000e+05
# 25%      70.000000   507.500000     1.000000     1.000000  7.550000e+05
# 50%      80.000000   878.000000     1.000000     1.500000  1.350000e+06
# 75%      85.000000  1320.500000     2.000000     2.000000  2.250000e+06
# max      96.000000  9768.000000     3.000000     3.500000  1.762500e+07

# %%
smaller_df = smaller_df[mask]

# %%
smaller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 0 to 1999
# Data columns (total 6 columns):
# bldg_rating    1928 non-null float64
# sold_season    1999 non-null object
# square_feet    1999 non-null int64
# beds           1999 non-null float64
# baths          1995 non-null float64
# sold_price     1999 non-null float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 109.3+ KB

# %%
smaller_df = smaller_df.dropna(how = 'any')

# %%
smaller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1924 entries, 0 to 1999
# Data columns (total 6 columns):
# bldg_rating    1924 non-null float64
# sold_season    1924 non-null object
# square_feet    1924 non-null int64
# beds           1924 non-null float64
# baths          1924 non-null float64
# sold_price     1924 non-null float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 105.2+ KB

# %%
import seaborn as sns
# %matplotlib inline
sns.set()
sns.pairplot(smaller_df, diag_kind='kde')

# %%
smaller_df.corr()
# Out:
#              bldg_rating  square_feet      beds     baths  sold_price
# bldg_rating     1.000000     0.418541  0.279038  0.467157    0.449774
# square_feet     0.418541     1.000000  0.462570  0.638309    0.902368
# beds            0.279038     0.462570  1.000000  0.786187    0.427378
# baths           0.467157     0.638309  0.786187  1.000000    0.623855
# sold_price      0.449774     0.902368  0.427378  0.623855    1.000000

# %%
sns.distplot(smaller_df['sold_price'])

# %%
categorical = ['sold_season']
continuous = ['bldg_rating', 'square_feet', 'beds', 'baths']

smaller_df = pd.get_dummies(smaller_df)
smaller_df.head()
# Out:
#    bldg_rating  square_feet  beds  baths  sold_price  sold_season_Fall  \
# 0         78.0          650   1.0    1.0    799000.0                 1
# 1         70.0          907   1.0    1.0   1739990.0                 1
# 2         80.0         1441   2.0    2.5   1782000.0                 1
# 3         62.0         1420   2.0    2.0   1800000.0                 1
# 4         91.0         1209   2.0    2.0   2195000.0                 1
#
#    sold_season_Spring  sold_season_Summer  sold_season_Winter
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0

# %% [markdown]
# # Model

# %%
# Necessary imports
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge #ordinary linear regression + w/ ridge regularization
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
smaller_df.head()
# Out:
#    bldg_rating sold_season  square_feet  beds  baths  sold_price
# 0         78.0        Fall          650   1.0    1.0    799000.0
# 1         70.0        Fall          907   1.0    1.0   1739990.0
# 2         80.0        Fall         1441   2.0    2.5   1782000.0
# 3         62.0        Fall         1420   2.0    2.0   1800000.0
# 4         91.0        Fall         1209   2.0    2.0   2195000.0

# %%
target = ['sold_price']
categorical = ['sold_season']
continuous = ['bldg_rating', 'square_feet', 'beds', 'baths']

X = smaller_df.drop('sold_price', axis = 1)
y = smaller_df['sold_price']

# %%
# hold out 20% of the data for final testing
X, X_test, y, y_test = train_test_split(X, y, test_size=.2, random_state=10)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, shuffle=True, random_state = 1000)

lm = LinearRegression()

np.mean(cross_val_score(lm, X, y, # estimator, features, target
                cv=kf, # number of folds 
                scoring='r2')) # scoring metric
# Out:
# 0.82855763584414

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

lm_reg = Ridge(alpha=1)

np.mean(cross_val_score(lm_reg, X, y, cv=kf, scoring = 'r2'))
#mean(cross_val_score)
# Out:
# 0.8285620865463255
